# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
read_file = pd.read_csv('C:/Msc Data Science/Assignments/archive/Top_Spotify_Songs_2023.csv',encoding = 'latin1')

# %%
# 1. Understanding the Data

# %%
read_file.shape
# Out:
# (953, 24)

# %%
read_file.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
read_file.tail()
# Out:
#                     track_name      artist(s)_name  artist_count  \
# 948               My Mind & Me        Selena Gomez             1
# 949  Bigger Than The Whole Sky        Taylor Swift             1
# 950       A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951              En La De Ella  Feid, Sech, Jhayco             3
# 952                      Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
read_file.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
read_file.dtypes
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts        object
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %%
read_file.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
read_file.nunique()
# Out:
# track_name              943
# artist(s)_name          645
# artist_count              8
# released_year            50
# released_month           12
# released_day             31
# in_spotify_playlists    879
# in_spotify_charts        82
# streams                 949
# in_apple_playlists      234
# in_apple_charts         172
# in_deezer_playlists     348
# in_deezer_charts         34
# in_shazam_charts        198
# bpm                     124
# key                      11
# mode                      2
# danceability_%           72
# valence_%                94
# energy_%                 80
# acousticness_%           98
# instrumentalness_%       39
# liveness_%               68
# speechiness_%            48
# dtype: int64

# %%
# cleaning the data

# %%
read_file.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
updated_read_file = read_file.drop(['in_shazam_charts','key'],axis = 1)

# %%
updated_read_file.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'bpm', 'mode',
#        'danceability_%', 'valence_%', 'energy_%', 'acousticness_%',
#        'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
New_file = updated_read_file.rename(columns = {'track_name':'Track_Name','artist(s)_name':'Artist(s)_Name','artist_count':'Artist_Count','released_year':'Released_Year','released_month':'Released_Month','released_day':'Released_Day','in_spotify_playlists':'In_Spotify_Playlists','in_spotify_charts':'In_Spotify_Charts','streams':'Streams','in_apple_playlists':'In_Apple_Playlists','in_apple_charts':'In_Apple_Charts','in_deezer_playlists':'In_Deezer_Playlists','in_deezer_charts':'In_Deezer_Charts','bpm':'Bpm','mode':'Mode','danceability_%':'Danceability_%','valence_%':'Valence','energy_%':'Energy','acousticness_%':'Acousticness_%','instrumentalness_%':'Instrumentalness_%','liveness_%':'Liveness_%','speechiness_%':'Speechiness_%'})

# %%
New_file
New_file.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 948    False
# 949    False
# 950    False
# 951    False
# 952    False
# Length: 953, dtype: bool

# %%
New_file.columns
# Out:
# Index(['Track_Name', 'Artist(s)_Name', 'Artist_Count', 'Released_Year',
#        'Released_Month', 'Released_Day', 'In_Spotify_Playlists',
#        'In_Spotify_Charts', 'Streams', 'In_Apple_Playlists', 'In_Apple_Charts',
#        'In_Deezer_Playlists', 'In_Deezer_Charts', 'Bpm', 'Mode',
#        'Danceability_%', 'Valence', 'Energy', 'Acousticness_%',
#        'Instrumentalness_%', 'Liveness_%', 'Speechiness_%'],
#       dtype='object')

# %%
New_file
# Out:
#                               Track_Name      Artist(s)_Name  Artist_Count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
# Relationship Analysis

# %%
Artist_Count = New_file['Artist(s)_Name'].value_counts()
Artist_Count
# Out:
# Artist(s)_Name
# Taylor Swift                 34
# The Weeknd                   22
# Bad Bunny                    19
# SZA                          19
# Harry Styles                 17
#                              ..
# Karol G, Ovy On The Drums     1
# Coolio, L.V.                  1
# Kordhell                      1
# Kenia OS                      1
# Feid, Sech, Jhayco            1
# Name: count, Length: 645, dtype: int64

# %%
Top_10_Artist = Artist_Count.head(10)
Top_10_Artist
# Out:
# Artist(s)_Name
# Taylor Swift      34
# The Weeknd        22
# Bad Bunny         19
# SZA               19
# Harry Styles      17
# Kendrick Lamar    12
# Morgan Wallen     11
# Ed Sheeran         9
# BTS                8
# Feid               8
# Name: count, dtype: int64

# %%
# Bar Graph of Top 10 Artist with Most Songs

# %%
def top_10_artists_bar_plot(Top_10_Artist):
    """
    This fucntion draws a bar chart to show the top 10 artists who has highest number of songs in the year 2023
    
    """
    plt.figure(figsize=(10, 8))
    barplot = sns.barplot(x=Top_10_Artist.index, y=Top_10_Artist.values, palette='viridis')
    plt.title('Top 10 Artists with Most Top Songs on Spotify',fontsize=15)
    plt.xlabel('Artists Name',fontsize=15)
    plt.ylabel('Number of Songs',fontsize=15)
    plt.ylim(0, 40)
    plt.xticks(rotation=45,fontsize=12)

    for bars in barplot.patches:
        barplot.annotate(format(bars.get_height(), '.0f'), 
                         (bars.get_x() + bars.get_width() / 2., bars.get_height()), 
                         ha='center', va='center', 
                         xytext=(0, 10), 
                         textcoords='offset points')
    plt.tight_layout()
    plt.savefig('top_10_artists_2023_bar_graph.png', dpi=500)

    plt.show()

top_10_artists_bar_plot(Top_10_Artist)

# %%
# Scatter Plot

# %%
def valence_vs_energy_scatter_plot(New_file):
    """
    Draws a scatter Graph comparing 'Valence' and 'Energy' for a given dataset.

    This function takes a DataFrame[New_file] as input and creates a scatter plot to visualize
    the relationship between 'Valence' and 'Energy' percentages of songs. 

    
    """
    plt.figure(figsize=(10, 8))
    plt.scatter(New_file['Valence'], New_file['Energy'], color='green', alpha=0.5, edgecolors='w', s=80)
    plt.title("Scatter plot between Valence and Energy ",fontsize=15)
    plt.xlabel('Valence',fontsize=15)
    plt.ylabel('Energy',fontsize=15)
    plt.grid(True)
    plt.savefig('top_10_artists_2023_scatter_graph.png', dpi=300)
    plt.show()

valence_vs_energy_scatter_plot(New_file)

# %%
# Correlation Heat map Analysis

# %%
def correlation_heatmap_plot(New_file):
    """
    Creates a correlation heatmap for numerical columns in the given DataSet.

    This function selects numerical columns from the provided DataFrame[New_file] and calculates
    the correlation matrix using seaborn's heatmap function.

    """
    numeric_file = New_file.select_dtypes(include=['float64', 'int64'])

    Correlation_Matrix = numeric_file.corr()
    plt.figure(figsize=(14, 12))
    sns.heatmap(Correlation_Matrix, annot=True, cmap='coolwarm')
    plt.title('Correlation Heatmap',fontsize=20)
    plt.xticks(fontsize=18)
    plt.yticks(fontsize=18)
    plt.savefig('top_10_artists_2023_heat_map.png', dpi=500)
    plt.show()
correlation_heatmap_plot(New_file)
